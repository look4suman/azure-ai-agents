# %% [markdown]
# ## Multi-Tool Calling with MAF and Microsoft Foundry

# %% [markdown]
# ![mutliple-tools](./Assets/multiple-tools.png)

# %%
# %pip install agent-framework==1.0.0b251209 python-dotenv azure-ai-projects==2.0.0b2
# Out:
# Requirement already satisfied: agent-framework==1.0.0b251209 in .\.venv\lib\site-packages (1.0.0b251209)
# Requirement already satisfied: python-dotenv in .\.venv\lib\site-packages (1.2.1)
# Requirement already satisfied: azure-ai-projects==2.0.0b2 in .\.venv\lib\site-packages (2.0.0b2)
# Requirement already satisfied: agent-framework-core==1.0.0b251209 in .\.venv\lib\site-packages (from agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.0.0b251209)
# Requirement already satisfied: isodate>=0.6.1 in .\.venv\lib\site-packages (from azure-ai-projects==2.0.0b2) (0.7.2)
# Requirement already satisfied: azure-core>=1.35.0 in .\.venv\lib\site-packages (from azure-ai-projects==2.0.0b2) (1.36.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in .\.venv\lib\site-packages (from azure-ai-projects==2.0.0b2) (4.15.0)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in .\.venv\lib\site-packages (from azure-ai-projects==2.0.0b2) (12.28.0b1)
# Requirement already satisfied: pydantic<3,>=2 in .\.venv\lib\site-packages (from agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (2.12.5)
# Requirement already satisfied: pydantic-settings<3,>=2 in .\.venv\lib\site-packages (from agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (2.12.0)
# Requirement already satisfied: opentelemetry-api>=1.39.0 in .\.venv\lib\site-packages (from agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.39.0)
# Requirement already satisfied: opentelemetry-sdk>=1.39.0 in .\.venv\lib\site-packages (from agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.39.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.39.0 in .\.venv\lib\site-packages (from agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.39.0)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai>=0.4.13 in .\.venv\lib\site-packages (from agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.4.13)
# Requirement already satisfied: openai>=1.99.0 in .\.venv\lib\site-packages (from agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (2.9.0)
# Requirement already satisfied: azure-identity<2,>=1 in .\.venv\lib\site-packages (from agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.26.0b1)
# Requirement already satisfied: mcp>=1.13 in .\.venv\lib\site-packages (from mcp[ws]>=1.13->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.23.3)
# Requirement already satisfied: packaging>=24.1 in .\.venv\lib\site-packages (from agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (25.0)
# Requirement already satisfied: agent-framework-a2a in .\.venv\lib\site-packages (from agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.0.0b251209)
# Requirement already satisfied: agent-framework-ag-ui in .\.venv\lib\site-packages (from agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.0.0b251209)
# Requirement already satisfied: agent-framework-azure-ai-search in .\.venv\lib\site-packages (from agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.0.0b251209)
# Requirement already satisfied: agent-framework-anthropic in .\.venv\lib\site-packages (from agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.0.0b251209)
# Requirement already satisfied: agent-framework-azure-ai in .\.venv\lib\site-packages (from agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.0.0b251209)
# Requirement already satisfied: agent-framework-azurefunctions in .\.venv\lib\site-packages (from agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.0.0b251209)
# Requirement already satisfied: agent-framework-chatkit in .\.venv\lib\site-packages (from agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.0.0b251209)
# Requirement already satisfied: agent-framework-copilotstudio in .\.venv\lib\site-packages (from agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.0.0b251209)
# Requirement already satisfied: agent-framework-declarative in .\.venv\lib\site-packages (from agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.0.0b251209)
# Requirement already satisfied: agent-framework-devui in .\.venv\lib\site-packages (from agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.0.0b251209)
# Requirement already satisfied: agent-framework-lab in .\.venv\lib\site-packages (from agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.0.0b251024)
# Requirement already satisfied: agent-framework-mem0 in .\.venv\lib\site-packages (from agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.0.0b251209)
# Requirement already satisfied: agent-framework-purview in .\.venv\lib\site-packages (from agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.0.0b251209)
# Requirement already satisfied: agent-framework-redis in .\.venv\lib\site-packages (from agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.0.0b251209)
# Requirement already satisfied: requests>=2.21.0 in .\.venv\lib\site-packages (from azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (2.32.5)
# Requirement already satisfied: cryptography>=2.1.4 in .\.venv\lib\site-packages (from azure-storage-blob>=12.15.0->azure-ai-projects==2.0.0b2) (46.0.3)
# Requirement already satisfied: msal>=1.30.0 in .\.venv\lib\site-packages (from azure-identity<2,>=1->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in .\.venv\lib\site-packages (from azure-identity<2,>=1->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.3.1)
# Requirement already satisfied: cffi>=2.0.0 in .\.venv\lib\site-packages (from cryptography>=2.1.4->azure-storage-blob>=12.15.0->azure-ai-projects==2.0.0b2) (2.0.0)
# Requirement already satisfied: anyio>=4.5 in .\.venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (4.12.0)
# Requirement already satisfied: httpx-sse>=0.4 in .\.venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in .\.venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in .\.venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (4.25.1)
# Requirement already satisfied: pyjwt>=2.10.1 in .\.venv\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in .\.venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.0.20)
# Requirement already satisfied: pywin32>=310 in .\.venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in .\.venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (3.0.3)
# Requirement already satisfied: starlette>=0.27 in .\.venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.50.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in .\.venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in .\.venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.38.0)
# Requirement already satisfied: websockets>=15.0.1 in .\.venv\lib\site-packages (from mcp[ws]>=1.13->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (15.0.1)
# Requirement already satisfied: distro<2,>=1.7.0 in .\.venv\lib\site-packages (from openai>=1.99.0->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in .\.venv\lib\site-packages (from openai>=1.99.0->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.12.0)
# Requirement already satisfied: sniffio in .\.venv\lib\site-packages (from openai>=1.99.0->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.3.1)
# Requirement already satisfied: tqdm>4 in .\.venv\lib\site-packages (from openai>=1.99.0->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (4.67.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in .\.venv\lib\site-packages (from opentelemetry-api>=1.39.0->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (8.7.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in .\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.39.0->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.72.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.66.2 in .\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.39.0->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.76.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.0 in .\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.39.0->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.39.0)
# Requirement already satisfied: opentelemetry-proto==1.39.0 in .\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.39.0->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.39.0)
# Requirement already satisfied: protobuf<7.0,>=5.0 in .\.venv\lib\site-packages (from opentelemetry-proto==1.39.0->opentelemetry-exporter-otlp-proto-grpc>=1.39.0->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (5.29.5)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b0 in .\.venv\lib\site-packages (from opentelemetry-sdk>=1.39.0->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.60b0)
# Requirement already satisfied: annotated-types>=0.6.0 in .\.venv\lib\site-packages (from pydantic<3,>=2->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in .\.venv\lib\site-packages (from pydantic<3,>=2->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (2.41.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in .\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in .\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (2025.11.12)
# Requirement already satisfied: a2a-sdk>=0.3.5 in .\.venv\lib\site-packages (from agent-framework-a2a->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.3.20)
# Requirement already satisfied: ag-ui-protocol>=0.1.9 in .\.venv\lib\site-packages (from agent-framework-ag-ui->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.1.10)
# Requirement already satisfied: fastapi>=0.115.0 in .\.venv\lib\site-packages (from agent-framework-ag-ui->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.124.2)
# Requirement already satisfied: anthropic<1,>=0.70.0 in .\.venv\lib\site-packages (from agent-framework-anthropic->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.75.0)
# Requirement already satisfied: azure-ai-agents==1.2.0b5 in .\.venv\lib\site-packages (from agent-framework-azure-ai->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.2.0b5)
# Requirement already satisfied: aiohttp in .\.venv\lib\site-packages (from agent-framework-azure-ai->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (3.13.2)
# Requirement already satisfied: azure-search-documents==11.7.0b2 in .\.venv\lib\site-packages (from agent-framework-azure-ai-search->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (11.7.0b2)
# Requirement already satisfied: azure-common>=1.1 in .\.venv\lib\site-packages (from azure-search-documents==11.7.0b2->agent-framework-azure-ai-search->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.1.28)
# Requirement already satisfied: azure-functions in .\.venv\lib\site-packages (from agent-framework-azurefunctions->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.25.0b3.dev1)
# Requirement already satisfied: azure-functions-durable in .\.venv\lib\site-packages (from agent-framework-azurefunctions->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.4.0)
# Requirement already satisfied: openai-chatkit<2.0.0,>=1.4.0 in .\.venv\lib\site-packages (from agent-framework-chatkit->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.4.0)
# Requirement already satisfied: microsoft-agents-copilotstudio-client>=0.3.1 in .\.venv\lib\site-packages (from agent-framework-copilotstudio->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.7.0.dev10)
# Requirement already satisfied: powerfx>=0.0.31 in .\.venv\lib\site-packages (from agent-framework-declarative->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.0.33)
# Requirement already satisfied: pyyaml<7.0,>=6.0 in .\.venv\lib\site-packages (from agent-framework-declarative->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (6.0.3)
# Requirement already satisfied: mem0ai>=0.1.117 in .\.venv\lib\site-packages (from agent-framework-mem0->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.0.1)
# Requirement already satisfied: redis>=6.4.0 in .\.venv\lib\site-packages (from agent-framework-redis->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (6.4.0)
# Requirement already satisfied: redisvl>=0.8.2 in .\.venv\lib\site-packages (from agent-framework-redis->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.12.1)
# Requirement already satisfied: numpy>=2.2.6 in .\.venv\lib\site-packages (from agent-framework-redis->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (2.4.0rc1)
# Requirement already satisfied: google-api-core>=1.26.0 in .\.venv\lib\site-packages (from a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (2.28.1)
# Requirement already satisfied: docstring-parser<1,>=0.15 in .\.venv\lib\site-packages (from anthropic<1,>=0.70.0->agent-framework-anthropic->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.17.0)
# Requirement already satisfied: pycparser in .\.venv\lib\site-packages (from cffi>=2.0.0->cryptography>=2.1.4->azure-storage-blob>=12.15.0->azure-ai-projects==2.0.0b2) (2.23)
# Requirement already satisfied: annotated-doc>=0.0.2 in .\.venv\lib\site-packages (from fastapi>=0.115.0->agent-framework-ag-ui->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.0.4)
# Requirement already satisfied: httpcore==1.* in .\.venv\lib\site-packages (from httpx>=0.27.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.0.9)
# Requirement already satisfied: h11>=0.16 in .\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.27.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in .\.venv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.39.0->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (3.23.0)
# Requirement already satisfied: attrs>=22.2.0 in .\.venv\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in .\.venv\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in .\.venv\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in .\.venv\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.30.0)
# Requirement already satisfied: posthog>=3.5.0 in .\.venv\lib\site-packages (from mem0ai>=0.1.117->agent-framework-mem0->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (7.0.1)
# Requirement already satisfied: pytz>=2024.1 in .\.venv\lib\site-packages (from mem0ai>=0.1.117->agent-framework-mem0->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (2025.2)
# Requirement already satisfied: qdrant-client>=1.9.1 in .\.venv\lib\site-packages (from mem0ai>=0.1.117->agent-framework-mem0->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.16.1)
# Requirement already satisfied: sqlalchemy>=2.0.31 in .\.venv\lib\site-packages (from mem0ai>=0.1.117->agent-framework-mem0->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (2.0.45)
# Requirement already satisfied: microsoft-agents-hosting-core==0.7.0.dev10 in .\.venv\lib\site-packages (from microsoft-agents-copilotstudio-client>=0.3.1->agent-framework-copilotstudio->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.7.0.dev10)
# Requirement already satisfied: microsoft-agents-activity==0.7.0.dev10 in .\.venv\lib\site-packages (from microsoft-agents-hosting-core==0.7.0.dev10->microsoft-agents-copilotstudio-client>=0.3.1->agent-framework-copilotstudio->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.7.0.dev10)
# Requirement already satisfied: openai-agents>=0.3.2 in .\.venv\lib\site-packages (from openai-chatkit<2.0.0,>=1.4.0->agent-framework-chatkit->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.6.2)
# Requirement already satisfied: jinja2<4,>=3.1 in .\.venv\lib\site-packages (from openai-chatkit<2.0.0,>=1.4.0->agent-framework-chatkit->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (3.1.6)
# Requirement already satisfied: pythonnet==3.0.5 in .\.venv\lib\site-packages (from powerfx>=0.0.31->agent-framework-declarative->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (3.0.5)
# Requirement already satisfied: clr_loader<0.3.0,>=0.2.7 in .\.venv\lib\site-packages (from pythonnet==3.0.5->powerfx>=0.0.31->agent-framework-declarative->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.2.9)
# Requirement already satisfied: jsonpath-ng>=1.5.0 in .\.venv\lib\site-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.7.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.4.0 in .\.venv\lib\site-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.5.4)
# Requirement already satisfied: python-ulid>=3.0.0 in .\.venv\lib\site-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (3.1.0)
# Requirement already satisfied: tenacity>=8.2.2 in .\.venv\lib\site-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (9.1.2)
# Requirement already satisfied: colorama in .\.venv\lib\site-packages (from tqdm>4->openai>=1.99.0->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.4.6)
# Requirement already satisfied: click>=7.0 in .\.venv\lib\site-packages (from uvicorn>=0.31.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core==1.0.0b251209->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (8.3.1)
# Requirement already satisfied: httptools>=0.6.3 in .\.venv\lib\site-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.7.1)
# Requirement already satisfied: watchfiles>=0.13 in .\.venv\lib\site-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.1.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in .\.venv\lib\site-packages (from aiohttp->agent-framework-azure-ai->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in .\.venv\lib\site-packages (from aiohttp->agent-framework-azure-ai->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in .\.venv\lib\site-packages (from aiohttp->agent-framework-azure-ai->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in .\.venv\lib\site-packages (from aiohttp->agent-framework-azure-ai->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in .\.venv\lib\site-packages (from aiohttp->agent-framework-azure-ai->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in .\.venv\lib\site-packages (from aiohttp->agent-framework-azure-ai->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.22.0)
# Requirement already satisfied: werkzeug~=3.1.3 in .\.venv\lib\site-packages (from azure-functions->agent-framework-azurefunctions->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.8.0 in .\.venv\lib\site-packages (from azure-functions-durable->agent-framework-azurefunctions->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (2.9.0.post0)
# Requirement already satisfied: furl>=2.1.0 in .\.venv\lib\site-packages (from azure-functions-durable->agent-framework-azurefunctions->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (2.1.4)
# Requirement already satisfied: six>=1.8.0 in .\.venv\lib\site-packages (from furl>=2.1.0->azure-functions-durable->agent-framework-azurefunctions->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.17.0)
# Requirement already satisfied: orderedmultidict>=1.0.1 in .\.venv\lib\site-packages (from furl>=2.1.0->azure-functions-durable->agent-framework-azurefunctions->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.0.2)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in .\.venv\lib\site-packages (from google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.26.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in .\.venv\lib\site-packages (from google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (2.43.0)
# Requirement already satisfied: MarkupSafe>=2.0 in .\.venv\lib\site-packages (from jinja2<4,>=3.1->openai-chatkit<2.0.0,>=1.4.0->agent-framework-chatkit->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (3.0.3)
# Requirement already satisfied: ply in .\.venv\lib\site-packages (from jsonpath-ng>=1.5.0->redisvl>=0.8.2->agent-framework-redis->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (3.11)
# Requirement already satisfied: griffe<2,>=1.5.6 in .\.venv\lib\site-packages (from openai-agents>=0.3.2->openai-chatkit<2.0.0,>=1.4.0->agent-framework-chatkit->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (1.15.0)
# Requirement already satisfied: types-requests<3,>=2.0 in .\.venv\lib\site-packages (from openai-agents>=0.3.2->openai-chatkit<2.0.0,>=1.4.0->agent-framework-chatkit->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (2.32.4.20250913)
# Requirement already satisfied: backoff>=1.10.0 in .\.venv\lib\site-packages (from posthog>=3.5.0->mem0ai>=0.1.117->agent-framework-mem0->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (2.2.1)
# Requirement already satisfied: portalocker<4.0,>=2.7.0 in .\.venv\lib\site-packages (from qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (3.2.0)
# Requirement already satisfied: greenlet>=1 in .\.venv\lib\site-packages (from sqlalchemy>=2.0.31->mem0ai>=0.1.117->agent-framework-mem0->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (3.3.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in .\.venv\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in .\.venv\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in .\.venv\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (4.9.1)
# Requirement already satisfied: h2<5,>=3 in .\.venv\lib\site-packages (from httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in .\.venv\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in .\.venv\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (4.1.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in .\.venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.0b251209->agent-framework==1.0.0b251209) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Setting Up the Environment

# %%
import os
from dotenv import load_dotenv
from azure.core.credentials import AzureKeyCredential

load_dotenv()
project_endpoint = os.getenv("AI_FOUNDRY_PROJECT_ENDPOINT")
model = os.getenv("AI_FOUNDRY_DEPLOYMENT_NAME")

print("Project Endpoint: ", project_endpoint)
print("Model: ", model)
# Out:
# Project Endpoint:  https://namusopenaidemo.services.ai.azure.com/api/projects/rag-demo
# Model:  namus-gpt-4o

# %% [markdown]
# ### Loading the Code Interpreter Tool

# %%
from agent_framework import AgentRunResponse, ChatResponseUpdate, HostedCodeInterpreterTool

code_interpreter_tool = HostedCodeInterpreterTool()

# %% [markdown]
# ### Loading the Hosted MCP Tool

# %%
from agent_framework import HostedMCPTool

ms_learn_mcp_tool = HostedMCPTool(
    name = "Microsoft Learn MCP Tool",
    url = "https://learn.microsoft.com/api/mcp"
)

# %% [markdown]
# ### Creating our Mutli-Tooled Agent

# %%
from agent_framework.azure import AzureAIClient
from azure.identity.aio import AzureCliCredential
from azure.ai.projects.aio import AIProjectClient

async def create_multi_tool_agent():
    credential = AzureCliCredential()
    
    # creating the Foundry Project Client
    project_client = AIProjectClient(
        endpoint=project_endpoint,
        credential=credential
    )

    # creating a conversation using the OpenAI Client
    openai_client = project_client.get_openai_client()
    conversation = await openai_client.conversations.create()
    conversation_id = conversation.id
    print("Conversation ID: ", conversation_id)
    
    # creating the Azure AI Client to interact with the Agent in Foundry
    agent_client = AzureAIClient(
        project_client = project_client,
        conversation_id = conversation_id,
        model_deployment_name=model
    )
    
    # creating an agent in Foundry
    agent = agent_client.create_agent(
        name="multi-tool-agent",
        instructions="You are a helpful multi-tool agent",
        tools = [code_interpreter_tool, ms_learn_mcp_tool]
    )
    return agent, credential, agent_client

agent, credential, agent_client = await create_multi_tool_agent()

# %% [markdown]
# ### Creating an Async Function to Handle User Approvals

# %%
from agent_framework import ChatMessage

async def handle_approvals_with_thread(query: str, agent):
    result = await agent.run(query)
    while len(result.user_input_requests) > 0:
        new_input = []
        for user_input_needed in result.user_input_requests:
            new_input.append(
                ChatMessage(
                    role="user",
                    contents=[user_input_needed.create_response(True)],
                )
            )
        result = await agent.run(new_input)
    return result

# %% [markdown]
# ### Running Different Queries on the Agent

# %%
query = "Can you write a Python function to calculate the factorial of a number using recursion and give me the output for number 100"
response = await handle_approvals_with_thread(query, agent)

print("\n🧠 Assistant:\n", response)

# %%
thread = agent.get_new_thread()
query = "How to create an Azure storage account using az cli?"
response = await handle_approvals_with_thread(query, agent)

print("\n🧠 Assistant:\n", response)
