# %% [markdown]
# ## Getting Started with the Semantic Kernel SDK Agent Framework

# %% [markdown]
# #### Installing utilities and dependencies

# %%
# %pip install semantic-kernel==1.28.1
# Out:
# Collecting semantic-kernel==1.28.1
#   Downloading semantic_kernel-1.28.1-py3-none-any.whl.metadata (11 kB)
# Collecting aiohttp~=3.8 (from semantic-kernel==1.28.1)
#   Using cached aiohttp-3.13.5-cp313-cp313-win_amd64.whl.metadata (8.4 kB)
# Collecting cloudevents~=1.0 (from semantic-kernel==1.28.1)
#   Using cached cloudevents-1.12.1-py3-none-any.whl.metadata (7.2 kB)
# Collecting pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0 (from semantic-kernel==1.28.1)
#   Using cached pydantic-2.11.10-py3-none-any.whl.metadata (68 kB)
# Collecting pydantic-settings~=2.0 (from semantic-kernel==1.28.1)
#   Using cached pydantic_settings-2.13.1-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: defusedxml~=0.7 in d:\python-programs\azure-ai-agents\semantic-kernel\agent_framework\.venv\lib\site-packages (from semantic-kernel==1.28.1) (0.7.1)
# Collecting azure-identity>=1.13 (from semantic-kernel==1.28.1)
#   Using cached azure_identity-1.25.3-py3-none-any.whl.metadata (91 kB)
# Collecting numpy>=1.26.0 (from semantic-kernel==1.28.1)
#   Using cached numpy-2.4.4-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# Collecting openai>=1.67 (from semantic-kernel==1.28.1)
#   Using cached openai-2.31.0-py3-none-any.whl.metadata (31 kB)
# Collecting openapi_core<0.20,>=0.18 (from semantic-kernel==1.28.1)
#   Using cached openapi_core-0.19.5-py3-none-any.whl.metadata (6.6 kB)
# Collecting websockets<16,>=13 (from semantic-kernel==1.28.1)
#   Using cached websockets-15.0.1-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Collecting aiortc>=1.9.0 (from semantic-kernel==1.28.1)
#   Using cached aiortc-1.14.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting opentelemetry-api~=1.24 (from semantic-kernel==1.28.1)
#   Using cached opentelemetry_api-1.40.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-sdk~=1.24 (from semantic-kernel==1.28.1)
#   Using cached opentelemetry_sdk-1.40.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting prance~=23.6.21.0 (from semantic-kernel==1.28.1)
#   Using cached prance-23.6.21.0-py3-none-any.whl.metadata (13 kB)
# Collecting pybars4~=0.9 (from semantic-kernel==1.28.1)
#   Using cached pybars4-0.9.13-py3-none-any.whl
# Requirement already satisfied: jinja2~=3.1 in d:\python-programs\azure-ai-agents\semantic-kernel\agent_framework\.venv\lib\site-packages (from semantic-kernel==1.28.1) (3.1.6)
# Requirement already satisfied: nest-asyncio~=1.6 in d:\python-programs\azure-ai-agents\semantic-kernel\agent_framework\.venv\lib\site-packages (from semantic-kernel==1.28.1) (1.6.0)
# Collecting scipy>=1.15.1 (from semantic-kernel==1.28.1)
#   Using cached scipy-1.17.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp~=3.8->semantic-kernel==1.28.1)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp~=3.8->semantic-kernel==1.28.1)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in d:\python-programs\azure-ai-agents\semantic-kernel\agent_framework\.venv\lib\site-packages (from aiohttp~=3.8->semantic-kernel==1.28.1) (26.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp~=3.8->semantic-kernel==1.28.1)
#   Using cached frozenlist-1.8.0-cp313-cp313-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp~=3.8->semantic-kernel==1.28.1)
#   Using cached multidict-6.7.1-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp~=3.8->semantic-kernel==1.28.1)
#   Using cached propcache-0.4.1-cp313-cp313-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp~=3.8->semantic-kernel==1.28.1)
#   Using cached yarl-1.23.0-cp313-cp313-win_amd64.whl.metadata (82 kB)
# Collecting aioice<1.0.0,>=0.10.1 (from aiortc>=1.9.0->semantic-kernel==1.28.1)
#   Using cached aioice-0.10.2-py3-none-any.whl.metadata (4.1 kB)
# Collecting av<17.0.0,>=14.0.0 (from aiortc>=1.9.0->semantic-kernel==1.28.1)
#   Using cached av-16.1.0-cp313-cp313-win_amd64.whl.metadata (4.7 kB)
# Collecting cryptography>=44.0.0 (from aiortc>=1.9.0->semantic-kernel==1.28.1)
#   Using cached cryptography-46.0.7-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting google-crc32c>=1.1 (from aiortc>=1.9.0->semantic-kernel==1.28.1)
#   Using cached google_crc32c-1.8.0-cp313-cp313-win_amd64.whl.metadata (1.8 kB)
# Collecting pyee>=13.0.0 (from aiortc>=1.9.0->semantic-kernel==1.28.1)
#   Using cached pyee-13.0.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting pylibsrtp>=0.10.0 (from aiortc>=1.9.0->semantic-kernel==1.28.1)
#   Using cached pylibsrtp-1.0.0-cp310-abi3-win_amd64.whl.metadata (4.2 kB)
# Collecting pyopenssl>=25.0.0 (from aiortc>=1.9.0->semantic-kernel==1.28.1)
#   Using cached pyopenssl-26.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting azure-core>=1.31.0 (from azure-identity>=1.13->semantic-kernel==1.28.1)
#   Using cached azure_core-1.39.0-py3-none-any.whl.metadata (48 kB)
# Collecting msal>=1.35.1 (from azure-identity>=1.13->semantic-kernel==1.28.1)
#   Downloading msal-1.36.0-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions>=1.2.0 (from azure-identity>=1.13->semantic-kernel==1.28.1)
#   Using cached msal_extensions-1.3.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in d:\python-programs\azure-ai-agents\semantic-kernel\agent_framework\.venv\lib\site-packages (from azure-identity>=1.13->semantic-kernel==1.28.1) (4.15.0)
# Collecting deprecation<3.0,>=2.0 (from cloudevents~=1.0->semantic-kernel==1.28.1)
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\python-programs\azure-ai-agents\semantic-kernel\agent_framework\.venv\lib\site-packages (from jinja2~=3.1->semantic-kernel==1.28.1) (3.0.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\python-programs\azure-ai-agents\semantic-kernel\agent_framework\.venv\lib\site-packages (from openai>=1.67->semantic-kernel==1.28.1) (4.13.0)
# Collecting distro<2,>=1.7.0 (from openai>=1.67->semantic-kernel==1.28.1)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\python-programs\azure-ai-agents\semantic-kernel\agent_framework\.venv\lib\site-packages (from openai>=1.67->semantic-kernel==1.28.1) (0.28.1)
# Collecting jiter<1,>=0.10.0 (from openai>=1.67->semantic-kernel==1.28.1)
#   Using cached jiter-0.13.0-cp313-cp313-win_amd64.whl.metadata (5.3 kB)
# Collecting sniffio (from openai>=1.67->semantic-kernel==1.28.1)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai>=1.67->semantic-kernel==1.28.1)
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting isodate (from openapi_core<0.20,>=0.18->semantic-kernel==1.28.1)
#   Using cached isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: jsonschema<5.0.0,>=4.18.0 in d:\python-programs\azure-ai-agents\semantic-kernel\agent_framework\.venv\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel==1.28.1) (4.26.0)
# Collecting jsonschema-path<0.4.0,>=0.3.1 (from openapi_core<0.20,>=0.18->semantic-kernel==1.28.1)
#   Using cached jsonschema_path-0.3.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting more-itertools (from openapi_core<0.20,>=0.18->semantic-kernel==1.28.1)
#   Using cached more_itertools-11.0.1-py3-none-any.whl.metadata (41 kB)
# Collecting openapi-schema-validator<0.7.0,>=0.6.0 (from openapi_core<0.20,>=0.18->semantic-kernel==1.28.1)
#   Using cached openapi_schema_validator-0.6.3-py3-none-any.whl.metadata (5.4 kB)
# Collecting openapi-spec-validator<0.8.0,>=0.7.1 (from openapi_core<0.20,>=0.18->semantic-kernel==1.28.1)
#   Using cached openapi_spec_validator-0.7.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting parse (from openapi_core<0.20,>=0.18->semantic-kernel==1.28.1)
#   Using cached parse-1.21.1-py2.py3-none-any.whl.metadata (21 kB)
# Collecting werkzeug<3.1.2 (from openapi_core<0.20,>=0.18->semantic-kernel==1.28.1)
#   Using cached werkzeug-3.1.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting importlib-metadata<8.8.0,>=6.0 (from opentelemetry-api~=1.24->semantic-kernel==1.28.1)
#   Using cached importlib_metadata-8.7.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting opentelemetry-semantic-conventions==0.61b0 (from opentelemetry-sdk~=1.24->semantic-kernel==1.28.1)
#   Using cached opentelemetry_semantic_conventions-0.61b0-py3-none-any.whl.metadata (2.5 kB)
# Collecting chardet>=3.0 (from prance~=23.6.21.0->semantic-kernel==1.28.1)
#   Using cached chardet-7.4.1-cp313-cp313-win_amd64.whl.metadata (9.4 kB)
# Collecting ruamel.yaml>=0.17.10 (from prance~=23.6.21.0->semantic-kernel==1.28.1)
#   Using cached ruamel_yaml-0.19.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: requests>=2.25 in d:\python-programs\azure-ai-agents\semantic-kernel\agent_framework\.venv\lib\site-packages (from prance~=23.6.21.0->semantic-kernel==1.28.1) (2.33.1)
# Requirement already satisfied: six~=1.15 in d:\python-programs\azure-ai-agents\semantic-kernel\agent_framework\.venv\lib\site-packages (from prance~=23.6.21.0->semantic-kernel==1.28.1) (1.17.0)
# Requirement already satisfied: packaging>=21.3 in d:\python-programs\azure-ai-agents\semantic-kernel\agent_framework\.venv\lib\site-packages (from prance~=23.6.21.0->semantic-kernel==1.28.1) (26.0)
# Collecting PyMeta3>=0.5.1 (from pybars4~=0.9->semantic-kernel==1.28.1)
#   Using cached pymeta3-0.5.1-py3-none-any.whl
# Collecting annotated-types>=0.6.0 (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0->semantic-kernel==1.28.1)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0->semantic-kernel==1.28.1)
#   Using cached pydantic_core-2.33.2-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0->semantic-kernel==1.28.1)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings~=2.0->semantic-kernel==1.28.1)
#   Using cached python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Collecting dnspython>=2.0.0 (from aioice<1.0.0,>=0.10.1->aiortc>=1.9.0->semantic-kernel==1.28.1)
#   Using cached dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting ifaddr>=0.2.0 (from aioice<1.0.0,>=0.10.1->aiortc>=1.9.0->semantic-kernel==1.28.1)
#   Using cached ifaddr-0.2.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: idna>=2.8 in d:\python-programs\azure-ai-agents\semantic-kernel\agent_framework\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai>=1.67->semantic-kernel==1.28.1) (3.11)
# Requirement already satisfied: cffi>=2.0.0 in d:\python-programs\azure-ai-agents\semantic-kernel\agent_framework\.venv\lib\site-packages (from cryptography>=44.0.0->aiortc>=1.9.0->semantic-kernel==1.28.1) (2.0.0)
# Requirement already satisfied: certifi in d:\python-programs\azure-ai-agents\semantic-kernel\agent_framework\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.67->semantic-kernel==1.28.1) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in d:\python-programs\azure-ai-agents\semantic-kernel\agent_framework\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.67->semantic-kernel==1.28.1) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\python-programs\azure-ai-agents\semantic-kernel\agent_framework\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.67->semantic-kernel==1.28.1) (0.16.0)
# Collecting zipp>=3.20 (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api~=1.24->semantic-kernel==1.28.1)
#   Using cached zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\python-programs\azure-ai-agents\semantic-kernel\agent_framework\.venv\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel==1.28.1) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\python-programs\azure-ai-agents\semantic-kernel\agent_framework\.venv\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel==1.28.1) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in d:\python-programs\azure-ai-agents\semantic-kernel\agent_framework\.venv\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel==1.28.1) (0.30.0)
# Requirement already satisfied: PyYAML>=5.1 in d:\python-programs\azure-ai-agents\semantic-kernel\agent_framework\.venv\lib\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel==1.28.1) (6.0.3)
# Collecting pathable<0.5.0,>=0.4.1 (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel==1.28.1)
#   Using cached pathable-0.4.4-py3-none-any.whl.metadata (1.8 kB)
# Collecting referencing>=0.28.4 (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel==1.28.1)
#   Using cached referencing-0.36.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting PyJWT<3,>=1.0.0 (from PyJWT[crypto]<3,>=1.0.0->msal>=1.35.1->azure-identity>=1.13->semantic-kernel==1.28.1)
#   Using cached pyjwt-2.12.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: rfc3339-validator in d:\python-programs\azure-ai-agents\semantic-kernel\agent_framework\.venv\lib\site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel==1.28.1) (0.1.4)
# Collecting lazy-object-proxy<2.0.0,>=1.7.1 (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.20,>=0.18->semantic-kernel==1.28.1)
#   Using cached lazy_object_proxy-1.12.0-cp313-cp313-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\python-programs\azure-ai-agents\semantic-kernel\agent_framework\.venv\lib\site-packages (from requests>=2.25->prance~=23.6.21.0->semantic-kernel==1.28.1) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\python-programs\azure-ai-agents\semantic-kernel\agent_framework\.venv\lib\site-packages (from requests>=2.25->prance~=23.6.21.0->semantic-kernel==1.28.1) (2.6.3)
# Requirement already satisfied: colorama in d:\python-programs\azure-ai-agents\semantic-kernel\agent_framework\.venv\lib\site-packages (from tqdm>4->openai>=1.67->semantic-kernel==1.28.1) (0.4.6)
# Requirement already satisfied: pycparser in d:\python-programs\azure-ai-agents\semantic-kernel\agent_framework\.venv\lib\site-packages (from cffi>=2.0.0->cryptography>=44.0.0->aiortc>=1.9.0->semantic-kernel==1.28.1) (3.0)
# Downloading semantic_kernel-1.28.1-py3-none-any.whl (809 kB)
#    ---------------------------------------- 0.0/809.6 kB ? eta -:--:--
#    ---------------------------------------- 809.6/809.6 kB 7.8 MB/s eta 0:00:00
# Using cached aiohttp-3.13.5-cp313-cp313-win_amd64.whl (458 kB)
# Using cached aiortc-1.14.0-py3-none-any.whl (93 kB)
# Using cached azure_identity-1.25.3-py3-none-any.whl (192 kB)
# Using cached cloudevents-1.12.1-py3-none-any.whl (55 kB)
# Using cached numpy-2.4.4-cp313-cp313-win_amd64.whl (12.3 MB)
# Using cached openai-2.31.0-py3-none-any.whl (1.2 MB)
# Using cached openapi_core-0.19.5-py3-none-any.whl (106 kB)
# Using cached opentelemetry_api-1.40.0-py3-none-any.whl (68 kB)
# Using cached opentelemetry_sdk-1.40.0-py3-none-any.whl (141 kB)
# Using cached opentelemetry_semantic_conventions-0.61b0-py3-none-any.whl (231 kB)
# Using cached prance-23.6.21.0-py3-none-any.whl (36 kB)
# Using cached pydantic-2.11.10-py3-none-any.whl (444 kB)
# Using cached pydantic_core-2.33.2-cp313-cp313-win_amd64.whl (2.0 MB)
# Using cached pydantic_settings-2.13.1-py3-none-any.whl (58 kB)
# Using cached scipy-1.17.1-cp313-cp313-win_amd64.whl (36.5 MB)
# Using cached websockets-15.0.1-cp313-cp313-win_amd64.whl (176 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aioice-0.10.2-py3-none-any.whl (24 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached av-16.1.0-cp313-cp313-win_amd64.whl (31.7 MB)
# Using cached azure_core-1.39.0-py3-none-any.whl (218 kB)
# Using cached chardet-7.4.1-cp313-cp313-win_amd64.whl (942 kB)
# Using cached cryptography-46.0.7-cp311-abi3-win_amd64.whl (3.5 MB)
# Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached frozenlist-1.8.0-cp313-cp313-win_amd64.whl (43 kB)
# Using cached google_crc32c-1.8.0-cp313-cp313-win_amd64.whl (34 kB)
# Using cached importlib_metadata-8.7.1-py3-none-any.whl (27 kB)
# Using cached jiter-0.13.0-cp313-cp313-win_amd64.whl (202 kB)
# Using cached jsonschema_path-0.3.4-py3-none-any.whl (14 kB)
# Downloading msal-1.36.0-py3-none-any.whl (121 kB)
# Using cached msal_extensions-1.3.1-py3-none-any.whl (20 kB)
# Using cached multidict-6.7.1-cp313-cp313-win_amd64.whl (45 kB)
# Using cached openapi_schema_validator-0.6.3-py3-none-any.whl (8.8 kB)
# Using cached openapi_spec_validator-0.7.2-py3-none-any.whl (39 kB)
# Using cached propcache-0.4.1-cp313-cp313-win_amd64.whl (40 kB)
# Using cached pyee-13.0.1-py3-none-any.whl (15 kB)
# Using cached pylibsrtp-1.0.0-cp310-abi3-win_amd64.whl (1.6 MB)
# Using cached pyopenssl-26.0.0-py3-none-any.whl (57 kB)
# Using cached python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Using cached ruamel_yaml-0.19.1-py3-none-any.whl (118 kB)
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached werkzeug-3.1.1-py3-none-any.whl (224 kB)
# Using cached yarl-1.23.0-cp313-cp313-win_amd64.whl (87 kB)
# Using cached isodate-0.7.2-py3-none-any.whl (22 kB)
# Using cached more_itertools-11.0.1-py3-none-any.whl (72 kB)
# Using cached parse-1.21.1-py2.py3-none-any.whl (19 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached dnspython-2.8.0-py3-none-any.whl (331 kB)
# Using cached ifaddr-0.2.0-py3-none-any.whl (12 kB)
# Using cached lazy_object_proxy-1.12.0-cp313-cp313-win_amd64.whl (26 kB)
# Using cached pathable-0.4.4-py3-none-any.whl (9.6 kB)
# Using cached pyjwt-2.12.1-py3-none-any.whl (29 kB)
# Using cached referencing-0.36.2-py3-none-any.whl (26 kB)
# Using cached zipp-3.23.0-py3-none-any.whl (10 kB)
# Installing collected packages: PyMeta3, parse, ifaddr, zipp, werkzeug, websockets, typing-inspection, tqdm, sniffio, ruamel.yaml, referencing, python-dotenv, PyJWT, pyee, pydantic-core, pybars4, propcache, pathable, numpy, multidict, more-itertools, lazy-object-proxy, jiter, isodate, google-crc32c, frozenlist, dnspython, distro, deprecation, chardet, av, annotated-types, aiohappyeyeballs, yarl, scipy, pylibsrtp, pydantic, prance, jsonschema-path, importlib-metadata, cryptography, cloudevents, azure-core, aiosignal, aioice, pyopenssl, pydantic-settings, opentelemetry-api, openai, aiohttp, opentelemetry-semantic-conventions, openapi-schema-validator, msal, aiortc, opentelemetry-sdk, openapi-spec-validator, msal-extensions, openapi_core, azure-identity, semantic-kernel
#   Attempting uninstall: referencing
#     Found existing installation: referencing 0.37.0
#     Uninstalling referencing-0.37.0:
#       Successfully uninstalled referencing-0.37.0
# Successfully installed PyJWT-2.12.1 PyMeta3-0.5.1 aiohappyeyeballs-2.6.1 aiohttp-3.13.5 aioice-0.10.2 aiortc-1.14.0 aiosignal-1.4.0 annotated-types-0.7.0 av-16.1.0 azure-core-1.39.0 azure-identity-1.25.3 chardet-7.4.1 cloudevents-1.12.1 cryptography-46.0.7 deprecation-2.1.0 distro-1.9.0 dnspython-2.8.0 frozenlist-1.8.0 google-crc32c-1.8.0 ifaddr-0.2.0 importlib-metadata-8.7.1 isodate-0.7.2 jiter-0.13.0 jsonschema-path-0.3.4 lazy-object-proxy-1.12.0 more-itertools-11.0.1 msal-1.36.0 msal-extensions-1.3.1 multidict-6.7.1 numpy-2.4.4 openai-2.31.0 openapi-schema-validator-0.6.3 openapi-spec-validator-0.7.2 openapi_core-0.19.5 opentelemetry-api-1.40.0 opentelemetry-sdk-1.40.0 opentelemetry-semantic-conventions-0.61b0 parse-1.21.1 pathable-0.4.4 prance-23.6.21.0 propcache-0.4.1 pybars4-0.9.13 pydantic-2.11.10 pydantic-core-2.33.2 pydantic-settings-2.13.1 pyee-13.0.1 pylibsrtp-1.0.0 pyopenssl-26.0.0 python-dotenv-1.2.2 referencing-0.36.2 ruamel.yaml-0.19.1 scipy-1.17.1 semantic-kernel-1.28.1 sniffio-1.3.1 tqdm-4.67.3 typing-inspection-0.4.2 websockets-15.0.1 werkzeug-3.1.1 yarl-1.23.0 zipp-3.23.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in d:\python-programs\azure-ai-agents\semantic-kernel\agent_framework\.venv\lib\site-packages (1.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# #### Creating the Kernel and the AzureChatCompletion Client

# %%
from semantic_kernel import Kernel
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion
from semantic_kernel.functions import KernelArguments
import os
import asyncio
import time
from dotenv import load_dotenv

kernel = Kernel()

load_dotenv()
# Load environment variables from .env file
api_key = os.getenv("AZURE_OPENAI_API_KEY")
deployment_name = os.getenv("AZURE_OPENAI_CHAT_COMPLETION_MODEL")
endpoint = os.getenv("AZURE_OPENAI_ENDPOINT")

print(f"Deployment Name: {deployment_name}")
print(f"Endpoint: {endpoint}")

service_id = "service1"
kernel.add_service(
    AzureChatCompletion(service_id=service_id,
                        api_key=api_key,
                        deployment_name=deployment_name,
                        endpoint = endpoint
    )
)

# %% [markdown]
# #### Creating the Agent with the AzureChatCompletionClient

# %%
from semantic_kernel.agents import ChatCompletionAgent
from semantic_kernel.connectors.ai.prompt_execution_settings import PromptExecutionSettings
from semantic_kernel.functions.kernel_arguments import KernelArguments
from semantic_kernel.connectors.ai.function_choice_behavior import FunctionChoiceBehavior

arguments = KernelArguments(
        settings=PromptExecutionSettings(
            # Set the function_choice_behavior to auto to let the model
            # decide which function to use, and let the kernel automatically
            # execute the functions.
            function_choice_behavior=FunctionChoiceBehavior.Auto(),
        )
    )

# Create the agent using the kernel
agent = ChatCompletionAgent(
  kernel=kernel, 
  name="ChatCompletionAgent", 
  instructions="You are a helpful AI assistant",
  arguments=arguments
)

# %% [markdown]
# #### Sending a simplistic message to our agent

# %%
response = await agent.get_response(messages="Hello how are you?")
print(response)
# Out:
# Hello! I'm just a bunch of code, so I don't have feelings, but I'm here and ready to help you with whatever you need. How are you doing? 😊

# %% [markdown]
# #### Seeing Agent Chat History Thread in Action

# %%
from semantic_kernel.agents import ChatHistoryAgentThread

# Define the thread
thread = ChatHistoryAgentThread()

continueChat = True

while continueChat:
    user_input = input("Enter your query: ")
    if user_input.lower() == "exit":
        continueChat = False
        break
    response = await agent.get_response(messages=user_input, thread=thread)
    print(response)
# Out:
# Good day! I hope this message finds you well. How can I assist you today? 😊
# The term "Hollywood" has been associated with the American film industry since the early 20th century. The history of Hollywood as a major hub for filmmaking began around the 1910s, when filmmakers started moving to Southern California to take advantage of the region’s sunny weather and diverse landscapes.
#
# To give you a clearer sense of its "age":
#
# - **Hollywood's Early Days**: The name "Hollywood" was officially used in 1887 when it was established as a small community in California.
# - **Hollywood and Film Industry**: The first motion picture studio in Hollywood was built in 1911, and by the 1910s and 1920s, it became the center of the American film industry.
# - **Age of Hollywood (as of 2023)**: If we consider 1911 as the starting point of Hollywood tied to filmmaking, Hollywood is about **112 years old**.
#
# It has since grown into a global symbol of entertainment and filmmaking!
# Hello again! Let me know if there’s anything else you’d like to ask or talk about—I’m happy to help! 😊
# Is everything okay? Let me know how I can assist you!
# I'm here to help whenever you're ready. Feel free to share what's on your mind! 😊
# Is there something specific you'd like to ask or discuss? I'm here to assist you!
